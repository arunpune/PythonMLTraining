# %% [markdown]
# # Indus Ind Bank HR Analytic - Salary Prediction Batch 2 - 2021

# %% [markdown]
# here we are going to implement a HR Analytics Case-study

# %%
# Import the necessary libraries
import numpy as np 
import matplotlib.pyplot as plot
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
