# %%
a =10

# %%
print(a)

# %%
brand = 'Priyanka1'

# %%
print(brand)

# %%
a=b=c=10
print(a)

# %%
x,y,z=10,20,50
print(z)

# %%
name1='John'
name2='James'
print(name1)
print(name2)
text1='hello\
World'
print(text1)
multiline='''st1
...st2
....st3
'''
print(multiline)

# %%
1+2

# %%
1-2

# %%
2%1

# %%
2/1

# %%
a=10
b=20
b>a

# %%
a != b

# %%
a=10<10 or 2 >-1
print(a)

# %%
abc=10
abc*=100
print(abc)

# %%
pets = ['dog','cat','wolf']
print(pets)

'cha' in pets

# %%
a =10

# %%
a ='saket'

# %%
message = 'hello word'
print(message)
print(type(message))

# %%
message=1234.8
print(message)
print(type(message))

# %%
var = 'helloworld'
print(var)
print(type(var))
print(var[0])
print(var[1:6])

# %%
str='Attachment'
str.find('me')

# %%
str.replace('me','xy')

# %%
str1='word1,word2,word3'
str1.split(',')

# %%
myGroup =('a','b','c','d')

# %%
print(myGroup)

# %%
#concatenation
myGroup  += ('f',)

# %%
print(myGroup)

# %%
myGroup *2

# %%
myGroup[2]

# %%
myGroup[2:5]

# %%
#list

myList=['a','b',10,7.12,'data']
print(myList)

# %%
myList *2

# %%
myList[1:3]

# %%
myList.append('d')
myList

# %%
myList.extend(['c','d'])
myList

# %%
myDict ={1:'John', 2:'Bob',3:'Alice' }
myDict

# %%
type(myDict)

# %%
myDict2 ={}
myDict2

# %%
myDict = {'name':'John', 1:[2,3,4]}
myDict

# %%
myDict = {'name':'John', 1:[2,3,4],2:[2,3,4]}
myDict

# %%
myDict[1]

# %%
len(myDict)

# %%
myDict.keys()

# %%
myDict.values()

# %%
mySet ={1,2,3}
print(mySet)

# %%
mySet1= {1,2,'c'}
mySet2={1,'b','c'}
mySet1|mySet2

# %%
type(mySet1)

# %%
mySet1.union(mySet2)

# %%
mySet1.intersection(mySet2)

# %%
mySet2.difference(mySet1)

# %%
f = open("Cars.csv","r")
print(f.read())

# %%
f = open("Cars.csv","r")
print(f.readline())
print(f.readline())

# %%
f = open("Cars.csv","r")
for x in f:
    print(x)

# %%
f = open("demofile.txt","a")
f.write("Now the file has a new line from Christoper")

# %%
#if else:
a =5
if a==5:
    print("True-a is 5")
    print("Rohan is a Data Analyst")
else:
    print("True- a is 4")
    
print("Sai is a Data Scientist")

# %%
print(z)

# %%
#for loop
n =25
#start-(end-1)-increment/decrement
for i in range (-6,0,1):
    print(i)
print('DDD')

# %%
n =2
i=1
while (i <=n):
    if (i==3):
        print(i)
        print("expression is less than 5")
     
    else:
        print("this is else expression")
    
    print(i)
    i=i+1
   
        
   
print("Good Bye")

# %%
def classify_on_age(age):
    classification =''
    if age <13:
        classification ='Hello Kid'
    elif age >=13 and age <20:
        classification = 'Hello Teenager'
    elif age >=20 and age <=25:
        classification ='Hello Adult'
    else :
        classification ='Hello Professional'
    return  classification 


output = classify_on_age(26)
print(output)
# Out:
# Hello Professional

# %%
def fun3(a,b,c=10):
    
    print(a,b,c)

# %%
fun3(40,50,30,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d5a921b761cb> in <module>
# ----> 1 fun3(40,50,30,20)
#
# TypeError: fun3() takes from 2 to 3 positional arguments but 4 were given

# %%
def fun4(*args):
    print(type(args),args)

# %%
fun4(10,'python',30,40,50,60,70)
# Out:
# <class 'tuple'> (10, 'python', 30, 40, 50, 60, 70)

# %%
def fun5(**keyaw):
    print(type(keyaw),keyaw)

# %%
fun5 (a=10,b='Python',age=50)
# Out:
# <class 'dict'> {'a': 10, 'b': 'Python', 'age': 50}

# %%
def func6 (a,b,c=10,*args,**keyaw):
    print(a,b,c)
    print(args)
    print(type(args),args)
    print(type(keyaw),keyaw)
    
    
func6(10,20,30,40,50,60,name='dari',age=28,business='soft')
# Out:
# 10 20 30
# (40, 50, 60)
# <class 'tuple'> (40, 50, 60)
# <class 'dict'> {'name': 'dari', 'age': 28, 'business': 'soft'}

# %%
def func(a):
    return a+10 if a>10 else a*20



print(func(9))
# Out:
# 180

# %%
abcd = lambda a:a*10 if a>10  else a*20

# %%
abcd(9)
# Out:
# 180

# %%
def squareit(x,y):
    return x*y

print(squareit(10,20))
# Out:
# 200

# %%
squareit2 = lambda x,y:x*y
print(squareit2(10,20))
# Out:
# 200
