# %% [markdown]
# # Python-Getting Started

# %% [markdown]
# Slide 9: Assigning single value to a variable…

# %%
a = 10
name = 'Victor'
salary = 2000.23
print (a)
print (name)
print (salary)

# %%
# Python code t get difference of two lists 


# compare Code 
li1 = [2,4,5,6,6,7]
li2 = [23,5,6,3,6,7] 
print(Diff(li1, li2))

# %%
a = 10
name = 'Victor'
salary = 2000.23
print (a)
print (name)
print (salary)

# %% [markdown]
# Slide 10 : Assigning multiple value to a variable…

# %%
a=b=c=10
x,y,z=10,20,30


print(a)
print(b)
print(y)
# Out:
# 10
# 10
# 20

# %%
#will throw an error
x,y,z=10,20
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-fab2237f1a2e> in <module>
#       1 #will throw an error
# ----> 2 x,y,z=10,20
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# Slide 14:String Literals, double quotes and single quotes

# %%
name1="John"
name2='James'
print(name1)
print(name2)
# Out:
# John
# James

# %% [markdown]
# triple quotes

# %%
multiline='''st1
st2
st3

line4'''
print(multiline)
# Out:
# st1
# st2
# st3
#
# line4

# %%
text1='hello\
World'

print(text1)
# Out:
# helloWorld

# %% [markdown]
# Slide 17: Special Literals: None
# Works like a null value, or empty value

# %%
val1 = 10
val2 = None
val1,val2
print(val1)
print(val2)
# Out:
# 10
# None

# %% [markdown]
# > # Operators

# %% [markdown]
# Slide : 19 Arithmetic Operator
# +, -, *, /, %

# %%
1+2
# Out:
# 3

# %%
1-2
# Out:
# -1

# %%
2%1
# Out:
# 0

# %% [markdown]
# Slide : 20 Assignment Operator =,+=, -=, *=

# %%
#a=10
#a=10*10
a*=10 #a=10*10
print(a)
# Out:
# 100

# %% [markdown]
# Slide 21: Comparison Operator <, >, <=, >=, !=

# %%
a = 10
b = 20 
a > b
#b > a
# Out:
# False

# %% [markdown]
# Slide 21: Comparison Operator <, >, <=, >=, !=

# %%
a = 10
b = 20 
a != b
# Out:
# True

# %% [markdown]
#  Slide 21: More  Operators =, +=, -=, *=

# %%
a = 10
a*=10#a=10*10
print(a)
# Out:
# 100

# %% [markdown]
# Logical Operator: and, or , not

# %%
a=10<10 and 2>-1
b=10<10 or 2>-1

print(a)
print(b)
# Out:
# False
# True

# %%
x = 10
x is 10
y=11
y is 10
# Out:
# False

# %%
x = 10
x is not 10
y= 11
y is not 10
# Out:
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-1-181b34b9d5af>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   x is not 10
# <ipython-input-1-181b34b9d5af>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   y is not 10
# True

# %% [markdown]
# Membership Operator in, not in

# %%
pets=['dog','cat','wolf']
print(pets)
#'lion' in pets
#'wolf' in pets
'me' in 'appointment'
# Out:
# ['dog', 'cat', 'wolf']
# True

# %% [markdown]
# # Datatypes in Python

# %% [markdown]
# > # Number : int, float

# %%
message = "Hello World"
num = 1234

pi = 13.6
print(message)
print(type(message)) #return a string
print(type(num)) #return an integer
print(type(pi)) #return a float
# Out:
# Hello World
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# > # Strings

# %%
var1 = 'Hello-World!'
var2 = 'PythonTutorial'

print(var1[0]) # prints the first character in the string `H`
print(var2[0:14]) # prints the substring 'ytho'
# Out:
# H
# PythonTutorial

# %% [markdown]
# find()

# %%
#find() – Returns the position of the string
str='Attachment'
str.find('a')
# Out:
# 3

# %% [markdown]
# replace()

# %%
#replace() – Replaces one character/string with other
str='Replacement'
str.replace('ce','e')
# Out:
# 'Replaement'

# %% [markdown]
# split()

# %%
#split() – Creates a split on the basis of a character
str='word1,word2,word3'
print(str)
str.split(',')
# Out:
# word1,word2,word3
# ['word1', 'word2', 'word3']

# %% [markdown]
# > # Tuples

# %%
myGroup = ('a', 'b', 'c', 'd')
print(myGroup)
# Out:
# ('a', 'b', 'c', 'd')

# %% [markdown]
# concatenation

# %%
#Concatenation - Adds two string/character
myGroup += ('f',)
print(myGroup)
# Out:
# ('a', 'b', 'c', 'd', 'f')

# %% [markdown]
# repetation

# %%
#Repetition -  Duplicate string/character by given number of times
myGroup * 2
# Out:
# ('a', 'b', 'c', 'd', 'f', 'a', 'b', 'c', 'd', 'f')

# %% [markdown]
# indexing

# %%
#Indexing - Shows the indexed character/string
myGroup = ('a', 'b', 'c', 'd', 'f')
myGroup[2]
# Out:
# 'c'

# %% [markdown]
# slicing

# %%
#Slicing – Shows a specific set of indexed character/string
myGroup = ('a', 'b', 'c', 'd', 'f')
myGroup[1:4]
a =myGroup.index('d')
print(a)
# Out:
# 3

# %% [markdown]
# > # List

# %%
myList= [1, 10, 2, 3]
print(myList)
# Out:
# [1, 10, 2, 3]

# %%
myGroup = ['a', 10, 7.12, 'data']

# %%
print(myGroup)
# Out:
# ['a', 10, 7.12, 'data']

# %% [markdown]
# concatenation

# %%
#Concatenation – Add elements to the list
myList = ['a', 1, 3.14, 'python']
myList+=['d',]
print(myList)
# Out:
# ['a', 1, 3.14, 'python', 'd']

# %% [markdown]
# repetation

# %%
#Repetition
myList = ['a', 1, 3.14, 'python']
myList*2
# Out:
# ['a', 1, 3.14, 'python', 'a', 1, 3.14, 'python']

# %% [markdown]
# slicing

# %%
#Slicing
myList = ['a', 1, 3.14, 'python']
myList = myList[0:3]
myList
print(type(myList))
#print(type(myList.index(0))
print(type(myList[0]))
print(type(myList[1]))
# Out:
# <class 'list'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
# append

# %%
#append(value)
myList = ['a', 1, 3.14, 'python']
myList.append('d')
myList

# %% [markdown]
# extend

# %%
#extend(list)
myList = ['a', 1, 3.14, 'python']
myList.extend (['c', 'd']) 
myList.

# %%
#str="hello"
#a =10
#str1 = str+a
#print(str1)

# %% [markdown]
# insert

# %%
#insert(index, value)
myList = ['a', 1, 3.14, 'python']
myList.insert(2, 'd')
myList
# Out:
# ['a', 1, 'd', 3.14, 'python']

# %% [markdown]
# > # Dictionary

# %% [markdown]
# Example

# %%
myDict = { 1: 'John' , 2: 'Bob', 3: 'Alice' }
print(myDict)
# Out:
# {1: 'John', 2: 'Bob', 3: 'Alice'}

# %% [markdown]
# Empty dictionary

# %%
#empty dictionary 
myDict = {}
print(myDict)
# Out:
# {}

# %% [markdown]
# Integer keys

# %%
#dictionary with integer keys
myDict = {1: 'apple', 2: 'ball'}
myDict[1]
# Out:
# 'apple'

# %%
#dictionary with mixed keys
myDict = {'name': 'John', 1: [2, 4, 3]}
myDict
# Out:
# {'name': 'John', 1: [2, 4, 3]}

# %% [markdown]
# mixed keys

# %%
#dictionary with mixed keys
myDict = {'name': 'John', 1: [2, 4, 3]}

# %%
#paring
#from sequence having each item as a pair
myDict = dict([(1,'apple'), (2,'ball')])
print(myDict)
# Out:
# {1: 'apple', 2: 'ball'}

# %%
#accessing dictionary
myDict = {1: 'word1', 2: 'word2'}
myDict[2]
# Out:
# 'word2'

# %%
#len()
myDict = {1: 'word1', 2: 'word2'}
len(myDict)
# Out:
# 2

# %%
#key()
myDict = {1:'apple', 2:'ball'}
len(myDict)
myDict.keys()
# Out:
# dict_keys([1, 2])

# %%
#values()
myDict = {1: 'apple', 2: 'ball'}
myDict.values()

myDict.
# Out:
# dict_values(['apple', 'ball'])

# %% [markdown]
# > # Sets

# %% [markdown]
# # Example

# %%
#mySet = {1, 2, 3}

# %%
#Creating set with duplicate values 
mySet = {1, 2, 3, 3}
print (mySet)
# Out:
# {1, 2, 3}

# %%
#Union of set
mySet1 = {1, 2, 'c'}
mySet2 = {1, 'b', 'c'}
mySet1|mySet2
# Out:
# {1, 2, 'b', 'c'}

# %%
type(mySet1)
# Out:
# set

# %%
mySet1.union(mySet2)
# Out:
# {1, 2, 'b', 'c'}

# %%
mySet1.intersection(mySet2)
# Out:
# {1, 'c'}

# %%
mySet1 = {1, 2, 'c','e'}
mySet2 = {1, 'b', 'c',}

#mySet1.difference(mySet2)
mySet2.difference(mySet1)
# Out:
# {'b'}

# %% [markdown]
# # File Handling

# %%
#File Handling in Jupyter using Pandas
import pandas as pd
#df1 = pd.read_csv("C:/PythonHow/income_data.csv")
df1 = pd.read_csv("C:/Users/HP/Downloads/Intelli/PythonDataScience/PythonNewConentGdrive/PythonNewcontent/Python_New_content/Module1_GettingStarted_With_python/CodeFiles/Cars.csv")
print(df1)

# %% [markdown]
# # Read

# %%
#Example
f = open("demofile.txt", "r")
#f = open("Cars.csv", "r")
print(f.read())
f.close()
# Out:
# This is HP Data Science Team

# %%
#Reading parts of file
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.read(5)) #Return the 5 first characters of the file
# Out:
# HP,MP

# %%
#Reading first line
f = open("demofile.txt", "r")
#f = open("Cars.csv", "r")
print(f.readline()) #readline() is used to return one line
# Out:
# This1 is HP Data Science Team

# %%
#Reading first line
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.readline()) 
print(f.readline()) # using readline() twice prints first two line
# Out:
# HP,MPG,VOL,SP,WT
#
# 49,53.70068138,89,104.1853528,28.7620589

# %%
#Loop through the file
#Read the file line by line
f = open("demofile.txt", "r")
#f = open("Cars.csv", "r")
for x in f:
  print(x)
# Out:
# This1 is HP Data Science Team
#
# This2 is HP Data Science Team
#
# This3 is HP Data Science Team
#
# This4 is HP Data Science Team

# %% [markdown]
# # Write/Create

# %%
#Example: Append
f = open("demofile.txt", "a")
f.write("Now the file has one more line!")
# Out:
# 31

# %%
#Example: Overwrite
f = open("demofile.txt", "w")
f.write("Woops! I have deleted the content!")

# %%
# Create a new file. If file exists it will give an error
f = open("myfile1.txt", "x")

# %% [markdown]
# # Delete

# %%
# Deleting the file
import os
#os.remove("test1.txt")

# %%
os.
