# %%
a = 10
name='Victor'
salary =2000.3

# %%
print(a)
# Out:
# 10

# %%
print(name)
print(salary)
# Out:
# Victor
# 2000.3

# %%
print(company)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14364\2323982806.py in <module>
# ----> 1 print(company)
#
# NameError: name 'company' is not defined

# %%
x,y,z =10,20,30

# %%
print(x)
# Out:
# 10

# %%
print(z)
# Out:
# 30

# %% [markdown]
# # Operators

# %%
operators
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14364\3438294494.py in <module>
# ----> 1 operators
#
# NameError: name 'operators' is not defined

# %%
1+2
# Out:
# 3

# %%
1-2
# Out:
# -1

# %%
6/2
# Out:
# 3.0

# %%
6%2
# Out:
# 0

# %% [markdown]
# # Assignment Operator =,+=, -=, *=

# %%
a=10
print(a)
# Out:
# 10

# %%
a=10*10
print(a)
# Out:
# 100

# %%
a=10
a*=10 #a=10*10
print(a)
# Out:
# 100

# %% [markdown]
# # Slide 21: Comparison Operator <, >, <=, >=, !=

# %%
a =10
b=20
a > b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a = b 
print(a)
# Out:
# 20

# %% [markdown]
# # data types of Pythong

# %%
message = "Hello World"
num = 1234
pi = 13.6

print(message)
print(type(message)) #return a string
print(type(num)) #return an integer
print(type(pi)) #return a float
# Out:
# Hello World
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
Tuples ?
List 
Dictionary
Sets

# %% [markdown]
# # File Handling

# %%
import pandas as pd
#df1 = pd.read_csv("C:/PythonHow/income_data.csv")
#df1 = pd.read_csv("C:/Users/HP/Downloads/Intelli/PythonDataScience/PythonNewConentGdrive/PythonNewcontent/Python_New_content/Module1_GettingStarted_With_python/CodeFiles/Cars.csv")
df1 = pd.read_csv("Cars.csv")
print(df1)
# Out:
#     HP        MPG  VOL          SP         WT
# 0   49  53.700681   89  104.185353  28.762059
# 1   55  50.013401   92  105.461264  30.466833
# 2   55  50.013401   92  105.461264  30.193597
# 3   70  45.696322   92  113.461264  30.632114
# 4   53  50.504232   92  104.461264  29.889149
# 5   70  45.696322   89  113.185353  29.591768
# 6   55  50.013401   92  105.461264  30.308480
# 7   62  46.716554   50  102.598513  15.847758
# 8   62  46.716554   50  102.598513  16.359484
# 9   80  42.299078   94  115.645204  30.920154
# 10  73  44.652834   89  111.185353  29.363341
# 11  92  39.354094   50  117.598513  15.753535
