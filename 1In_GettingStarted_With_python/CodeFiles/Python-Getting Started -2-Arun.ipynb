# %% [markdown]
# # Python-Getting Started

# %% [markdown]
# Slide 9: Assigning single value to a variable…

# %%
a = 10
name = 'Victor'
salary = 2000.23
print (a)
print (name)
print (salary)

# %%
# Python code t get difference of two lists 


# compare Code 
li1 = [2,4,5,6,6,7]
li2 = [23,5,6,3,6,7] 
print(Diff(li1, li2))

# %%
a = 10
name = 'Victor'
salary = 2000.23
print (a)
print (name)
print (salary)

# %% [markdown]
# Slide 10 : Assigning multiple value to a variable…

# %%
a=b=c=10
x,y,z=10,20,30
print(y)
print(a)

# %%
#will throw an error
x,y,z=10,20

# %% [markdown]
# Slide 14:String Literals

# %%
name1="John"
name2='James'
print(name1)
print(name2)
text1='hello\
World'
text1
print(text1)
multiline='''st1
...st2
...st3'''
print(multiline)

# %% [markdown]
# Slide 17: Special Literals: None
# Works like a null value, or empty value

# %%
val1 = 10
val2 = None
val1,val2
print(val2)

# %% [markdown]
# > # Operators

# %% [markdown]
# Slide : 19 Arithmetic Operator
# +, -, *, /, %

# %%
1+2

# %%
1-2

# %%
2%1

# %% [markdown]
# Slide : 20 Assignment Operator =,+=, -=, *=

# %%
a=10 
a*=10 #a=10*10
print(a)

# %% [markdown]
# Slide 21: Comparison Operator <, >, <=, >=, !=

# %%
a = 10
b = 20 
a > b

# %%
Slide 21: Comparison Operator <, >, <=, >=, !=

# %%
a = 10
b = 20 
a != b

# %% [markdown]
#  Slide 21: More  Operators =, +=, -=, *=

# %%
a = 10
a*=10#a=10*10
print(a)

# %% [markdown]
# Logical Operator: and, or , not

# %%
a=10<10 and 2>-1
print(a)

# %% [markdown]
# Bitwise Operator &,|,>>,<<,~

# %%
7 | 5

# %%
7 & 5

# %% [markdown]
# Identity Operator is, is not

# %%
x = 10
x is 10

# %%
x = 10
x is not 10

# %% [markdown]
# Membership Operator in, not in

# %%
pets=['dog','cat','wolf']
'lion' in pets
'wolf' in pets
'me' in 'appointment'

# %% [markdown]
# # Datatypes in Python

# %% [markdown]
# > # Number

# %%
message = "Hello World"
num = 1234
pi = 13.6
print(type(message)) #return a string
print(type(num)) #return an integer
print(type(pi)) #return a float

# %% [markdown]
# > # Strings

# %%
var1 = 'Hello-World!'
var2 = 'PythonTutorial'

print(var1[0]) # prints the first character in the string `H`
print(var2[1:5]) # prints the substring 'ytho'

# %% [markdown]
# find()

# %%
#find() – Returns the position of the string
str='Attachment'
str.find('Me')

# %% [markdown]
# replace()

# %%
#replace() – Replaces one character/string with other
str='Replacement'
str.replace('ed','e')

# %% [markdown]
# split()

# %%
#split() – Creates a split on the basis of a character
str='word1,word2,word3'
str.split(',')

# %% [markdown]
# # Difference between list and Tuples

# %%
https://www.afternerd.com/blog/difference-between-list-tuple/

# %% [markdown]
# > # Tuples

# %% [markdown]
# The pair is an example of a tuple. Generalizing this, a tuple can be used to group any number of items into a single compound value. Syntactically, a tuple is a comma-separated sequence of values. Although it is not necessary, it is conventional to enclose tuples in parentheses:

# %%
myGroup = ('a', 'b', 'c', 'd','1')
print(myGroup)

# %% [markdown]
# concatenation

# %%
#Concatenation - Adds two string/character
myGroup += ('f',)
print(myGroup)

# %% [markdown]
# repetation

# %%
#Repetition -  Duplicate string/character by given number of times
myGroup * 2

# %% [markdown]
# indexing

# %%
#Indexing - Shows the indexed character/string
myGroup = ('a', 'b', 'c', 'd', 'f')
myGroup[2]

# %% [markdown]
# slicing

# %%
#Slicing – Shows a specific set of indexed character/string
myGroup = ('a', 'b', 'c', 'd', 'f')
myGroup[1:4]

# %% [markdown]
# > # List

# %%
myGroup = ('a', 10, 7.12, 'data')

# %% [markdown]
# concatenation

# %%
#Concatenation – Add elements to the list
myList = ['a', 1, 3.14, 'python']
myList+=['d',]
print(myList)

# %% [markdown]
# repetation

# %%
#Repetition
myList = ['a', 1, 3.14, 'python']
myList*2

# %% [markdown]
# slicing

# %%
#Slicing
myList = ['a', 1, 3.14, 'python']
myList = myList[0:4]
myList

# %% [markdown]
# append

# %%
#append(value)
myList = ['a', 1, 3.14, 'python']
myList.append('d')
myList

# %% [markdown]
# extend

# %%
#extend(list)
myList = ['a', 1, 3.14, 'python']
myList.extend (['c', 'd']) 
myList

# %% [markdown]
# insert

# %%
#insert(index, value)
myList = ['a', 1, 3.14, 'python']
myList.insert(2, 'd')
myList

# %% [markdown]
# > # Dictionary

# %% [markdown]
# Example

# %%
myDict = { 1: 'John' , 2: 'Bob', 3: 'Alice' }

# %%
print(myDict)

# %% [markdown]
# Empty dictionary

# %%
#empty dictionary 
myDict = {}

# %%
print(myDict)

# %% [markdown]
# Integer keys

# %%
#dictionary with integer keys
myDict = {1: 'apple', 2: 'ball'}

# %%
print(myDict)

# %% [markdown]
# mixed keys

# %%
#dictionary with mixed keys
myDict2 = {'name': 'John', 1: [2, 4, 3]}

# %%
print(myDict2)

# %%
#paring
#from sequence having each item as a pair
myDict3 = dict([(1,'apple'), (2,'ball')])

# %%
print(myDict3)

# %%
#accessing dictionary
myDict4 = {1: 'word1', 2: 'word2',3: 'word3',4: 'word4',5: 'word5'}
myDict4[2]

# %%
#len()
#myDict = {1: 'word1', 2: 'word2'}
len(myDict)

# %%
#key()
myDict = {1:'apple', 2:'ball'}
print(len(myDict))
print(myDict.keys())

# %%
#values()
myDict = {1: 'apple', 2: 'ball'}
myDict.values()
['apple', 'ball']

# %% [markdown]
# # Removing Items in Dictionary

# %%
print(myDict3)
myDict3.pop(1)
print(myDict3)

# %%
print(myDict4)
myDict4.popitem()
print(myDict4)

# %% [markdown]
# > # Sets

# %% [markdown]
# in sets there will be no duplicates. values will not repeat

# %% [markdown]
# # Example

# %% [markdown]
# creating a set

# %%
set1 = set()
print(set1)

# %%
# Creating a Set of String   
set2 = set("GeeksForGeeks")  
print(set2)

# %%
# Creating a Set of List   
set3 = set(["Geeks", "For", "Geeks"]) 
print(set3)

# %% [markdown]
# Adding elements: Using add() and update()

# %%
# Addition of elements in a Set   

  
set4 = set() 
      
# Adding to the Set using add()  
set4.add(8) 
set4.add((6, 7)) 
print(set4)

# %% [markdown]
# # set-update

# %% [markdown]
# Python Set update() method example
# In the following example we have two Sets of numbers X & Y and we are calling X.update(Y) to add the elements of set Y to the Set X.
# The update() method updates the current set, by adding items from another set.
#
# If an item is present in both sets, only one appearance of this item will be present in the updated set.

# %%
# Set X
X = {1, 2, 3}

# Set Y
Y = {2, 3, 4}

# Displaying X & Y before update()
print("X is:",X)
print("Y is:",Y)

# Calling update() method
X.update(Y)

# Displaying X & Y after update()
print("X is:",X)
print("Y is:",Y)

# %% [markdown]
# Set update() method example with List, Tuple, String, Dictionary
# In the following example we are adding the elements of a list, tuple, string & dictionary to the calling set X using the update() method.

# %%
# Set X
X = {1, 2, 3}

# List lis
lis = [3, 5]

# tuple
t = (77, 99)

# String
s = "abc"

# Dictionary dict
dict = {"one": 1, "two": 2}

# Calling update() method
X.update(lis, t, s, dict)

# Displaying X after update()
print("X is:",X)

# %% [markdown]
# # Set - New Examples

# %%
mySet = {1, 2, 3}

# %%
#Creating set with duplicate values 
mySet = {1, 2, 3, 3}
print (mySet)

# %% [markdown]
# In Union the duplicates will occur only once

# %%
#Union of set
mySet1 = {1, 2, 'c'}
mySet2 = {1, 'b', 'c'}
mySet1|mySet2

# %%
type(mySet1)

# %%
mySet1.union(mySet2)

# %% [markdown]
# in Intersection only the Common Items will occur

# %%
mySet1.intersection(mySet2)

# %%
mySet1.difference(mySet2)

# %% [markdown]
# # How to input data in Jupyter

# %%
value= input("enter a string")

print('this is the new value:{}' .format(value))
# Out:
# enter a stringhello
# this is the new value:hello

# %%
# File Handling in Python

# %%
file = open('mobily.txt','r')
for each in file:
    print(each)
    
file.close()
# Out:
# This is new line1
#
# This is new line2

# %%
file = open('mobily.txt','r')
print(file.read())

file.close()
# Out:
# This is new line1
# This is new line2

# %%
file = open('mobily.txt','r')
print(file.read(20))
file.close()
# Out:
# This is new line1
# Th

# %%
file = open("mobily.txt","w")
file.write("This is new line1")
file.write("This is new line2")

file.close()

# %%
file = open("mobily.txt","w")

file.write("This is new line12\n")
file.write("This is new line2\n")
file.write("This is new line24\n")
file.write("This is new line25\n")
file.close()

# %%
file = open("testfile.txt","w") 
 
file.write("Hello World") 
file.write("This is our new text file") 
file.write("and this is another line.") 
file.write("Why? Because we can.") 
 
file.close()

# %%
file = open('mobily.txt','a')
file.write("\n this will add new line with append")

file.close()

# %%
with open ("mobily3.txt", "a") as f:
    f.write("hello write!!2")
    f.close()

# %%
with open ("mobily3.txt", "r") as file:
    data = file.readlines()
    for line in data:
        word = line.split()
        print(word)

# %% [markdown]
# # Reading from  a File

# %%
#file1 = open(r"C:\Users\arunk\Downloads\Intelli\IntelliDataSciencePython\PythonDataScience\1PythonTrainingToUSe\Module1_GettingStarted_With_python\CodeFiles\mobily.txt", "r")

# %%
#file2 = open(r"C:\Users\arunk\Downloads\Intelli\IntelliDataSciencePython\PythonDataScience\1PythonTrainingToUSe\Module1_GettingStarted_With_python\CodeFiles\mobily2.txt", "r+")

# %%
file1 = open("myfile.txt", "w")
L=["1This is Delhi \n", "Live in Paris\n", "Dance in  London\n"]
str= "This is Delhi  This is Paris This is London"
str.strip()
#write to file
file1.write("Hello\n")
file1.writelines(L)
file1.writelines(str)
file1.close()

# %%
#output the files
file1 = open("myfile.txt", "r+")
print("Output of the read function")
print(file1.read())
#print()

file1.seek(0)
print("Output")
#print(file1.read(35))
print(file1.readline(35))
print()


        
file1.close()

# %%
with open ("myfile.txt", "r") as file:
    data = file.read(2)
    for line in data:
        word = line.split()
        print(word)
        
file.close()

# %%
with open ("myfile.txt", "r") as file:
    data = file.readlines()
    for line in data:
        word = line.split()
        print(word)
        
file.close()

# %% [markdown]
# # File Handling

# %% [markdown]
# # Read CSV using Python - Pandas

# %%
#File Handling in Jupyter using Pandas
#import pandas as pd
import pandas

#df1 = pd.read_csv("C:/Users/HP/Downloads/Intelli/IntelliDataSciencePython/PythonDataScience/1PythonTrainingToUSe/Module1_GettingStarted_With_python/CodeFiles/Cars.csv")
#df1 = pd.read_csv("C:/Users/arunk/Downloads/Intelli/IntelliDataSciencePython/PythonDataScience/1PythonTrainingToUSe/Module1_GettingStarted_With_python/CodeFiles/Cars.csv")

df2 = pd.read_csv("C:\\Users\\arunk\\Downloads\\Intelli\\IntelliDataSciencePython\\PythonDataScience\\1PythonTrainingToUSe\\Module1_GettingStarted_With_python\\CodeFiles\\Cars.csv")

#C:\\Users\\arunk\\Downloads\\Intelli\\IntelliDataSciencePython\\PythonDataScience\\1PythonTrainingToUSe\\Module1_GettingStarted_With_python\\CodeFiles
    
#print(df1)
print(df2)

# %% [markdown]
# # Read CSV using Python

# %%
#Example
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.read())

# %%
#Reading parts of file
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.read(5)) #Return the 5 first characters of the file

# %%
#Reading first line
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.readline()) #readline() is used to return one line

# %%
#using readline() twice prints first two line
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.readline()) 
print(f.readline()) # using readline() twice prints first two line

# %%
#Loop through the file
#Read the file line by line
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
for x in f:
  print(x)

# %% [markdown]
# # Write/Create

# %%
#Example: Append
f = open("demofile.txt", "a")
f.write("Now the file has one more line!")

# %%
#Example: Overwrite
f = open("demofile.txt", "w")
f.write("Woops! I have deleted the content!")

# %%
# Create a new file. If file exists it will give an error
f = open("myfile1.txt", "x")

# %% [markdown]
# # Delete

# %%
# Deleting the file
import os
os.remove("demofile.txt")

# %% [markdown]
# # Mutable vs Immutable

# %% [markdown]
# # Underscore

# %% [markdown]
# what is the meaning of various types of underscore usage like
# 1. _abc
#
# single underscore _abc<br>
# it can be used <br>
# -Before a name<br>
# As per coding conventions it is to give a hint that _abc is to be used for internal purposes. it does not impact the code<br>
#
# -After a name<br>
# if you want to use a key word class, then say class_<br>
#
# 2.
# _abc_
#  _abc_ (_abc_ is removed by the interpreter and prints only abc)
#
#
# #3.
#
# __abc
# (defines the variable as private)
#
# *#* (__underscore__) are removed __abc__
#
# #this is for python keywords like __INIT__
# #if we use it as __abc__

# %% [markdown]
# # 3. __abc (defines the variable as private)

# %%
class Myclass(): 
    def __init__(self): 
        self.__variable = 10
        self.variablepublic=20
    ##here the variable is made as private
    def func(self):
        print( self.__variable )

# %%
obj = Myclass() 
#obj.__variable
#obj.__variable cannot be accessed
print(obj.variablepublic)
obj.func()
