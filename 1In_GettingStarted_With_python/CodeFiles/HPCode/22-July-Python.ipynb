# %% [markdown]
# # Tupule - ()

# %%
myGroup = ('a','b','c','d','e','f')

#list1 = ('a','b','c','d','e','f')
#print(list1)

# %%
print(myGroup.index('a'))
#print(myGroup.count())

# %%
print(type(myGroup))

# %%
myGroup2 =('a',1,'c','d')

# %%
print(myGroup2)

# %% [markdown]
# repetition of data

# %%
myGroup*2

# %%
myGroup[2]

# %%
myGroup[0:5]

# %%
print(myGroup)

# %% [markdown]
# Empty Tupule

# %%
myGroup3= ()

# %%
print(myGroup3)

# %% [markdown]
# single value Tupule

# %%
myGroup4=('a')

# %%
print(myGroup4)

# %% [markdown]
# # Tupule are IMMUTABLE - you cannot change values

# %%
tup1 = (12,3.56)
tup2= ('abc','xyz')

# %%
print(tup1)
print(tup2)

# %%
tup1[0]=10

# %% [markdown]
# # Immutable Tupules

# %%
 a = ("aples","bananas","oranges")

# %%
print(a)

# %%
print(id(a))

# %%
b = a

# %%
print(b)

# %%
print(id(b))

# %%
a=('berries', 'bananas', 'oranges')

# %%
print(id(a))

# %%
print(b)
print(id(b))

# %%
print(a)

# %% [markdown]
# # List

# %%
la = ["apple", "banas","oranges"]
print(la)
print(id(la))

# %%
lb = la

# %%
print(lb)
print(id(lb))

# %%
la.append("apples1")

# %%
print(la)
print(id(la))

# %%
print(lb)
print(id(lb))

# %% [markdown]
# create new tupule

# %% [markdown]
# concatenation of 2 tupules by  creating a 3rd new tupule

# %%
tup3=tup1+tup2

# %%
print(tup3)

# %% [markdown]
# immutable data types - int, string, floats,  tupules,

# %%
tup4=tup1+tup2

# %%
del tup4

# %%
print(tup4)

# %%
len(tup3)

# %%
print(type(tup3))

# %% [markdown]
# # LIST - []

# %%
myList =['a',1,3.14, 'python']

# %%
print(myList)

# %%
print(type(myList))

# %%
myList *2

# %% [markdown]
# slicing/indexing the data

# %%
myList[0]

# %%
myList[0:3]

# %% [markdown]
# # List are MUTABLE-you can change values

# %% [markdown]
# Append

# %%
myList.append('d')

# %%
print(myList)

# %% [markdown]
# insert in a specific index

# %%
myList.insert(2,'new value2')

# %%
print(myList)

# %%
myList [1]=2

# %%
print(myList)

# %%
myList [1]='new Value3'

# %%
print(myList)

# %%
#del myList
#myList will be lost and removed from the memory

# %%
myGroup3= myList

# %%
print(myGroup3)

# %%
print(type(myGroup3))

# %%
myList.insert(2,myGroup)

# %%
print(myList)

# %% [markdown]
# # Dictionary- {}, - Key and Values

# %%
myDictionary = {1:'John', 2:'Bob', 3:'Alice'}

# %%
myDictionary.keys()
myDictionary.values()

# %%
print(myDictionary)

# %%
print(myDictionary[3])

# %%
myDictionary2 = {'name1':'John', 'name2':'Bob', 'name3':'Alice'}

# %%
print(myDictionary2)

# %%
print(myDictionary2['name1'])

# %%
myDictionary3 = {'name1':'John', 1:[1,2,3,4], 'name2':'Alice',2:[1,2,3,4]}

# %%
print(myDictionary3[1])

# %%
print(myDictionary3['name1'])

# %%
myDictionary3.keys()

# %%
myDictionary3.values()

# %%
myDictionary3.keys

# %%
myDictionary4 = {1:'John', 1:[1,2,3,4], 1:'Alice',2:[1,2,3,4]}

# %%
print(myDictionary4)

# %%
myDictionary4.pop(2)

# %%
myDictionary4

# %%
myDictionary4.popitem()

# %%
myDictionary4

# %% [markdown]
# # Set

# %%
mySet ={1,2,3}

# %%
print(mySet)

# %% [markdown]
# Union - |

# %%
mySet1 ={1,2,'c'}
mySet2={1,'b','c'}

# %%
mySet1|mySet2

# %%
type(mySet1)

# %% [markdown]
# Union - Keyword

# %%
mySet1.union(mySet2)

# %%
print(mySet1,mySet2)

# %%
mySet1.intersection(mySet2)

# %%
print(mySet1,mySet2)

# %%
mySet1 & mySet2

# %%
mySet1.difference(mySet2)

# %%
mySet1.pop()

# %%
mySet1

# %%
print(mySet1,mySet2)

# %%
mySet1 ={1,2,'c','d'}
mySet2={1,'b','c'}

# %%
mySet1.update(mySet2)

# %%
mySet1

# %% [markdown]
# # Loops

# %% [markdown]
# # IF

# %%
if condition 
    statement1
    
statement2

# %%
i =10
if (i < 15):
    print("10 is less than 15")
else:
    print("X is greater than 15")
    
print("Iam not in If condition")

# %% [markdown]
# # If elif else ladder

# %%
#i = None
i=200
if (i==10):
    print("i is 10")
elif (i==15):
    print("i is 15")
elif (i==20):
    print("i is 20")
elif (i==30):
    print("i is 30")
else:
    print("i is not present")
    
print("This is outside of if")

# %% [markdown]
# Nested if

# %%
i = 10
if (i==10):
    print("i is 10")
    if (i<15):
        print("i is smaller than 15")
elif (i==15):
    print("i is 15")
elif (i==20):
    print("i is 20")
elif (i==30):
    print("i is 30")
else:
    print("i is not present")
    
print("This is outside of if")

# %% [markdown]
# # FOR LOOP

# %% [markdown]
# for Var in Interable:

# %% [markdown]
# '' or " "

# %% [markdown]
# '''
#
# '''

# %%
l =["this","is","a","list"]

# %%
for i in l:
    print(i)

# %%
t =("this","is","a","tupule")
for i in t:
    print(i)

# %%
d= dict()
d['xyz']=123
d['abc']=345
#d.keys()
#d.values()

for i in d:
    print("%s%  d"% (i,d[i]) )

# %%
d['xyz']=123
d['abc']=345

for i in d:
    print(i, d[i] )

# %% [markdown]
# # CONTINUE

# %%
for letter in "TestContinue":
    if letter =='C':
           continue
    print('current letter:',letter)
print('letter==\'C\' is true so skip but CONTINUE the Loop')

# %% [markdown]
# # Break

# %%
for letter in "TestBreak":
    if letter =='B':
           break
    print('current letter:',letter)
print('letter==\'B\' is true and so BREAK the loop and exit')

# %% [markdown]
# # Range

# %%
for i in range(5):
    print(i)

# %%
l =[10,20,30,40]
#print(len(l))
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 20
# 30
# 40

# %% [markdown]
# # Range (Start, End, Step Up)

# %%
#sum =0
#for i in range (1,10):
for i in range (1,10,3):
    print("Print the numbers:",i)
    #sum = sum + i
    #print("Print the numbers:",sum)
# Out:
# Print the numbers: 1
# Print the numbers: 4
# Print the numbers: 7

# %% [markdown]
# # For Else

# %%
for  i in range (1,4):
    print(i)
else:
    print("Else")
#print("Else")
#print("Else")
#print("Else")
# Out:
# 1
# 2
# 3
# Else

# %%
for n in range(2, 10):
    for x in range(2, n):
        if n % x == 0:
            print( n, 'equals', x, '*', n/x)
            break
    else:
        # loop fell through without finding a factor
        print(n, 'is a prime number')
# Out:
# 2 is a prime number
# 3 is a prime number
# 4 equals 2 * 2.0
# 5 is a prime number
# 6 equals 2 * 3.0
# 7 is a prime number
# 8 equals 2 * 4.0
# 9 equals 3 * 3.0

# %% [markdown]
# # While

# %%
count =0
while (count < 3):
    count = count +1
    print("Hello Team")
# Out:
# Hello Team
# Hello Team
# Hello Team

# %%
i=0
a ="whilecont"
while  i < len(a):
    if a[i]=='e' or a[i]=='h':
        
        print('cont:',i)
        i = i +1
        continue
        
    
    print("current letter:",a[i])
    print('whiletext:',i)
    i = i +1
# Out:
# current letter: w
# whiletext: 0
# cont: 1
# current letter: i
# whiletext: 2
# current letter: l
# whiletext: 3
# cont: 4
# current letter: c
# whiletext: 5
# current letter: o
# whiletext: 6
# current letter: n
# whiletext: 7
# current letter: t
# whiletext: 8

# %% [markdown]
# # While Else

# %%
i =0
while i <4:
    i += 1
    print(i)
else:
    print("this is else")
# Out:
# 1
# 2
# 3
# 4
# this is else

# %% [markdown]
# # Key Differences between LIST and TUPULE
# Mutable vs Immutable

# %% [markdown]
# LIST

# %%
l =["apples","bannas"]
print(l)
# Out:
# ['apples', 'bannas']

# %%
id(l)
# Out:
# 2403535427656

# %%
l[0]= "berries"

# %%
print(l)
# Out:
# ['berries', 'bannas']

# %%
id(l)
# Out:
# 2403535427656

# %% [markdown]
# TUPULE

# %%
t =("apples","bannas")
print(t)
# Out:
# ('apples', 'bannas')

# %%
id(t)
# Out:
# 2403535335048

# %%
t[0]= "berries"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-225d56ac220d> in <module>
# ----> 1 t[0]= "berries"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t =("berries","bannas")
print(t)
# Out:
# ('berries', 'bannas')

# %%
id(t)
# Out:
# 2403535424008

# %%
print(t[0])
# Out:
# berries

# %%
t[1]
# Out:
# 'bannas'

# %% [markdown]
# # Key Differences between LIST and TUPULE

# %% [markdown]
# # performance - When to use

# %%
#time taken by mutalble list
import time

def using_List():
    t1 = time.time()#Starting/Initial Time
    L=[]
    X = range(50000)
    for item in X:
        L.append(item)
    #print(L)
    return time.time()-t1

list_time = using_List()
print(list_time)
# Out:
# 0.004987478256225586

# %%
#time taken by Tupule which is immutable
import time

def using_Tupule():
    tt1 = time.time()#Starting/Initial Time
    T=()
    X = range(50000)
    for item in X:
        T = T + (item,)
        #single tuple needs a ,
    #print(T)
    return time.time()-tt1

Tupule_time = using_Tupule()
print(Tupule_time)
# Out:
# 6.006747007369995

# %% [markdown]
# # Debugging problems for Mutable Data Types

# %%
a=[1,3,5,7]
b=a

print(a)
print(id(a))
print(b)
print(id(b))
#to copy the values of the list to a new location
c=a.copy()

print(c)
print(id(c))
#to copy the values of the list to a new location- using key word list
d= list(a)

print(d)
print(id(d))
# Out:
# [1, 3, 5, 7]
# 2403581911432
# [1, 3, 5, 7]
# 2403581911432
# [1, 3, 5, 7]
# 2403581859144
# [1, 3, 5, 7]
# 2403577952968

# %%
b[0]=-10

print(b)
print(id(b))
# Out:
# [-10, 3, 5, 7]
# 2403581911432

# %%
print(a)
print(id(a))
# Out:
# [-10, 3, 5, 7]
# 2403581911432

# %% [markdown]
# # User Defined Functions and Passing Parameters

# %% [markdown]
# Create a function

# %%
def Classify_on_age(age):
    classification =""
    if age <= 13:
        classification ="Hello Kid"
    elif age > 13 and age < 20:
        classification ="Hello Teen"
    elif age > 20 and age < 25:
        classification ="Hello Adult"
        
    else: 
        classification ="Hello Professional"
    return classification

# %%
output=Classify_on_age(13)
print(output)
# Out:
# Hello Kid

# %%
def fun1(a,b,c):
    print (a,b,c)

# %%
def fun2(a,b,c):
    return (a,b,c)

# %%
fun1(40,50,60)
#print(fun1(10,20,30))
# Out:
# 40 50 60

# %%
def fun3(a,b,c):
    print (a,b,c)

# %%
fun3(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ee92dfd1e4ee> in <module>
# ----> 1 fun3(10,20)
#
# TypeError: fun3() missing 1 required positional argument: 'c'

# %% [markdown]
# Default Values

# %%
def fun4(a,b,c=10):
    print (a,b,c)

# %%
fun4(10,20)
# Out:
# 10 20 10

# %% [markdown]
# # Unlimited number of Parameters

# %% [markdown]
# *args will help pass unlimited number of parameters, *args is the coding convention, but any name can used

# %%
def fun5 (*args):
    print(args)
    print(type(args))

# %%
fun5(10,20,30,40,50,60,70)
# Out:
# (10, 20, 30, 40, 50, 60, 70)
# <class 'tuple'>

# %%
fun5(10,'python',30,40,50)
# Out:
# (10, 'python', 30, 40, 50)
# <class 'tuple'>

# %%
def fun6 (*custom):
    print(custom)
    print(type(custom))

# %%
fun6(10,'python',30,40,50)
# Out:
# (10, 'python', 30, 40, 50)
# <class 'tuple'>

# %% [markdown]
# # unlimited parameters as key value pair

# %%
def fun7 (**keyargs):
    print(keyargs)
    
    print(keyargs.keys())
    print(keyargs.values())
    print(type(keyargs))

# %%
fun7(a=10,b='Python', age=50)
# Out:
# {'a': 10, 'b': 'Python', 'age': 50}
# dict_keys(['a', 'b', 'age'])
# dict_values([10, 'Python', 50])
# <class 'dict'>

# %%
def fun8 (**keycustom):
    print(keycustom)
    print(type(keycustom))

# %%
fun8(a=10,b='Python', age=50)
# Out:
# {'a': 10, 'b': 'Python', 'age': 50}
# <class 'dict'>

# %% [markdown]
# # Return Dictionary

# %%
def fun9():
    
    dictTable={1:'name',2:'age',3:'gender'}
    
    return dictTable

# %%
a=fun9()
print(a)
# Out:
# {1: 'name', 2: 'age', 3: 'gender'}

# %% [markdown]
# # Pass a Unlimited  arguments and argument types

# %%
#def fun8 (**keycustom):

# %%
def fun11(a,b,c=10, *args, **keyargs):
    print(a,b,c)
    print (args)
    print(keyargs)

    
fun11(10,20,30,40,50,60,70,name='jack',age='30',business='Telecom',tel='120')
# Out:
# 10 20 30
# (40, 50, 60, 70)
# {'name': 'jack', 'age': '30', 'business': 'Telecom', 'tel': '120'}

# %% [markdown]
# # Pass a 'list' as an argument

# %%
def fun10(nameList):
    for x in nameList:
        print(x)

# %%
nameList =["jack","jill"]
fun10(nameList)
# Out:
# jack
# jill

# %% [markdown]
# # Pass a 'list' as an argument - Method 2- * args for iterables

# %%
# sum_integers_args_3
def my_sum(*args):
    result = 0
    for x in args:
        result += x
    return result

list1 = [1, 2, 3]
list2 = [4, 5]
list3 = [6, 7, 8, 9]

print(my_sum(*list1, *list2, *list3))
# Out:
# 45

# %% [markdown]
# # Passing parameters as Dictionary

# %%
# Python program to demonstrate 
# passing dictionary as argument 
# A function that takes dictionary 
# as an argument 
def func(d): 
	
	for key in d: 
		print("key:", key, "Value:", d[key]) 
		
# Driver's code 
D = {'a':1, 'b':2, 'c':3} 
func(D)
# Out:
# key: a Value: 1
# key: b Value: 2
# key: c Value: 3

# %% [markdown]
# # Pass a 'Dictionary' as an argument

# %%
# A function that takes dictionary  as an argument 
def func(d): 
	
	for key in d: 
		print("key:", key, "Value:", d[key]) 
		
# Driver's code 
D = {'a':1, 'b':2, 'c':3} 
func(D)
# Out:
# key: a Value: 1
# key: b Value: 2
# key: c Value: 3

# %% [markdown]
# # Pass a 'Dictionary' as an argument - Method 2, **args

# %%
# Python program to demonstrate 
# passing dictionary as kwargs 
def display(**name): 

    print (name["fname"]+" "+name["mname"]+" "+name["lname"]) 


    # passing dictionary key-value 
    # pair as arguments 
display(fname ="John", mname ="F.", lname ="Kennedy")
# Out:
# John F. Kennedy

# %% [markdown]
# # External output in Jupyter (Input)

# %% [markdown]
# # Print formatting - using % String Modulo

# %% [markdown]
# integer and floats for printing

# %%
print("Team: %d, Work: %.4f" % (1000.000,00050000.33999))
# Out:
# Team: 1000, Work: 50000.3400

# %%
print("Team: %d" % (2500000000000000000000000000000))
# Out:
# Team: 2500000000000000000000000000000

# %% [markdown]
# octal values -0

# %%
print("Team: %2o" % (2500000000000000000000000000000))
# Out:
# Team: 3743367610021300442454464000000000

# %%
print("Team: %10.3E"% (0500007.339999999999))
# Out:
# Team:  5.000E+05

# %% [markdown]
# # Print formatting - using {} placeholders

# %%
print("this is {} team for {}" .format('HP','football'))
# Out:
# this is HP team for football

# %%
print("this is {1} team for {0}" .format('HP','football'))
# Out:
# this is football team for HP

# %% [markdown]
# # integers -d and float -f

# %%
print("this is {1} team for {0}" .format('mobily','football'))
# Out:
# this is football team for mobily

# %%
print("this is {0:2.2f} team for {1:d}" .format(12.4445,200))
# Out:
# this is 12.44 team for 200

# %% [markdown]
# # Print dictionary p

# %%
#myDictionary4 = {1:'John', 1:[1,2,3,4], 1:'Alice',2:[1,2,3,4]}

#tab = {'empid':[127,3232,234], 'deptid':212}
tab = {'empid':127, 'deptid':212}
print(tab['empid'])
print(tab)
print("Empid: {0[empid]:d}; DeptId: {0[deptid]:f}" .format(tab))
# Out:
# 127
# {'empid': 127, 'deptid': 212}
# Empid: 127; DeptId: 212.000000

# %%
teamDict={'name':"Jack",'Team':"Mobily"}
print(teamDict)

print("Footballer {0[name]} plays for team {0[Team]}" .format(teamDict))
# Out:
# {'name': 'Jack', 'Team': 'Mobily'}
# Footballer Jack plays for team Mobily

# %% [markdown]
# # File Handling

# %%
'''
Open()
parameters:
    r : reading
    w : writing
    a : appending
various modificaitons to the above 
    r+
    w+
'''
# Out:
# '\nOpen()\nparameters:\n    r : reading\n    w : writing\n    a : appending\nvarious modificaitons to the above \n    r+\n    w+\n'

# %%
file1 = open("mobily.txt",'w')
file1.write("this is mobily team1\n")
file1.write("this is mobily team2\n")
file1.close()

# %% [markdown]
# # with

# %%
with open("mobily.txt") as file4:
    data = file4.read()
    print(data)
#file.close()
# Out:
# this is mobily team1
# this is mobily team2

# %% [markdown]
# split()

# %%
with open("mobily.txt","r") as file5:
    data = file5.readline()
   
    #for line in data:
    
    #word = line.split()
    #print(word)
    print(data)
# Out:
# this is mobily team1

# %%
with open("mobily.txt","r") as file5:
    data = file5.readlines()
    
    for line in data:
        word = line.split()
    print(word)
    print(data)
# Out:
# ['this', 'is', 'mobily', 'team2']
# ['this is mobily team1\n', 'this is mobily team2\n']

# %% [markdown]
# seek

# %%
with open("mobily.txt","r") as file7:
    data = file7.readlines()
    file7.seek(10)
    data = file7.readlines()
    print(data)
    file7.seek(7)
    #print(file7.read(7))
    data2 = file7.readlines()
    print(data2)
    #print(file7.read(50))
    
    #for line in data:
    #    word = line.split()
    #print(word)
    #print(data)
# Out:
# ['bily team1\n', 'this is mobily team2\n']
# [' mobily team1\n', 'this is mobily team2\n']

# %% [markdown]
# # Read Write operations using Multiple files

# %%
file8 = open("mobily2.txt","a")
L = ["this is mobily team4\n","this is mobily team5\n","this is mobily team6\n"]

file8.write("Hello\n")
file8.writelines(L)
file8.close()

# %%
with open("mobily2.txt","r") as file9:
    data = file9.readline()
    #file.seek(7)
    print(data)
    
    for line in data:
        word = line.split()
    print(word)
    #print(data)
# Out:
# Hello
#
# []

# %% [markdown]
# # File operations using Pandas

# %%
#File Handling in Jupyter using Pandas
import pandas as pd
#df1 = pd.read_csv("C:/Users/HP/Downloads/Intelli/IntelliDataSciencePython/PythonDataScience/1PythonTrainingToUSe/Module1_GettingStarted_With_python/CodeFiles/Cars.csv")
#df1 = pd.read_csv("C:/Users/arunk/Downloads/Intelli/IntelliDataSciencePython/PythonDataScience/1PythonTrainingToUSe/Module1_GettingStarted_With_python/CodeFiles/Cars.csv")

df2 = pd.read_csv("C:\\Users\\arunk\\Downloads\\Intelli\\IntelliDataSciencePython\\PythonDataScience\\1PythonTrainingToUSe\\Module1_GettingStarted_With_python\\CodeFiles\\Cars.csv")

#C:\\Users\\arunk\\Downloads\\Intelli\\IntelliDataSciencePython\\PythonDataScience\\1PythonTrainingToUSe\\Module1_GettingStarted_With_python\\CodeFiles
    
#print(df1)
print(df2)
# Out:
#     HP        MPG  VOL          SP         WT
# 0   49  53.700681   89  104.185353  28.762059
# 1   55  50.013401   92  105.461264  30.466833
# 2   55  50.013401   92  105.461264  30.193597
# 3   70  45.696322   92  113.461264  30.632114
# 4   53  50.504232   92  104.461264  29.889149
# 5   70  45.696322   89  113.185353  29.591768
# 6   55  50.013401   92  105.461264  30.308480
# 7   62  46.716554   50  102.598513  15.847758
# 8   62  46.716554   50  102.598513  16.359484
# 9   80  42.299078   94  115.645204  30.920154
# 10  73  44.652834   89  111.185353  29.363341
# 11  92  39.354094   50  117.598513  15.753535

# %% [markdown]
# Python Native FIle handling

# %%
#Example
#f = open("demofile.txt", "r")
f = open("Cars.csv", "r")
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-107-ac89a40d9dca> in <module>
#       1 #Example
#       2 #f = open("demofile.txt", "r")
# ----> 3 f = open("Cars.csv", "r")
#       4 print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Cars.csv'

# %%
#Example: Append
f = open("demofile2.txt", "a")
f.write("Now the file has one more line!")
f.close()

# %%
#Example: Overwrite
f = open("demofile.txt", "w")
f.write("Create teh file!")
#f.write("Woops! I have deleted the content!")
f.close()

# %%
# Deleting the file
import os
os.remove("demofile.txt")

# %% [markdown]
# # Lambda

# %%
a=lambda x: (x%2 != 0)
print(a(5))
# Out:
# True

# %% [markdown]
# # Using Filter() with Lambda

# %%
# Python code to illustrate 
# filter() with lambda() 
li = [5, 7, 22,24,26, 97, 54, 62, 77, 23, 73, 61] 
final_list = list(filter(lambda x: (x%2 != 0) , li)) 
print(final_list)
# Out:
# [5, 7, 97, 77, 23, 73, 61]

# %% [markdown]
# # function that filters vowels

# %%
# function that filters vowels

def fun(variable): 
	letters = ['a', 'e', 'i', 'o', 'u'] 
	if (variable in letters): 
		return True
	else: 
		return False


# sequence 
sequence = ['g', 'e', 'e', 'j', 'k', 's', 'p', 'r'] 

# using filter function
#we are creating list of vowels and filltering out only the vowels below:
filtered = filter(fun, sequence) 

print('The filtered letters are:') 
for s in filtered: 
	print(s)
# Out:
# The filtered letters are:
# e
# e

# %% [markdown]
# # Error and Exception Handling in Python

# %% [markdown]
# Examples of Different types of Error are Given Below:

# %%
int('five')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-3e382ef51cdd> in <module>
# ----> 1 int('five')
#
# ValueError: invalid literal for int() with base 10: 'five'

# %%
some_list=[1,2,3,4]
some_list[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-122-29be72ffa8fc> in <module>
#       1 some_list=[1,2,3,4]
# ----> 2 some_list[5]
#
# IndexError: list index out of range

# %%
a = "defined"
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-4c0c0a3a5db8> in <module>
#       1 a = "defined"
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
def func1():
a=1
print(a)
# Out:
#   File "<ipython-input-124-d9c5f3e7dc3e>", line 2
#     a=1
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# # Blocks for Error or Exception Handling

# %%
try: 
    #run the code
except:
    #executes the code when we there is an exception 
else: 
    #executes the code when thre is NO exception
finally: 
    #executes the code the code always

# %%
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
try:
  print(x)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")
# Out:
# Something went wrong
# The 'try except' is finished

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
#run the code
f = open("Cars.csv", "r")
print(f.read())
# Out:
# HP,MPG,VOL,SP,WT
# 49,53.70068138,89,104.1853528,28.7620589
# 55,50.01340115,92,105.4612635,30.46683298
# 55,50.01340115,92,105.4612635,30.19359657
# 70,45.69632238,92,113.4612635,30.63211391
# 53,50.50423183,92,104.4612635,29.88914864
# 70,45.69632238,89,113.1853528,29.59176832
# 55,50.01340115,92,105.4612635,30.30847957
# 62,46.71655428,50,102.5985128,15.84775807
# 62,46.71655428,50,102.5985128,16.35948352
# 80,42.29907817,94,115.6452041,30.92015417
# 73,44.65283424,89,111.1853528,29.36334142
# 92,39.3540941,50,117.5985128,15.75353468

# %%
#Example



try: 
    #run the code
    f = open("Cars.csv", "r")
    print(f.read())

except:
    #executes the code when there is an exception
    print("There is not file by this name")
else: 
    #executes the code when thre is NO exception
    print("There is a file by this name")
finally: 
    f.close()
    #executes the code the code always
    print("This runs always in the Finllay")
# Out:
# HP,MPG,VOL,SP,WT
# 49,53.70068138,89,104.1853528,28.7620589
# 55,50.01340115,92,105.4612635,30.46683298
# 55,50.01340115,92,105.4612635,30.19359657
# 70,45.69632238,92,113.4612635,30.63211391
# 53,50.50423183,92,104.4612635,29.88914864
# 70,45.69632238,89,113.1853528,29.59176832
# 55,50.01340115,92,105.4612635,30.30847957
# 62,46.71655428,50,102.5985128,15.84775807
# 62,46.71655428,50,102.5985128,16.35948352
# 80,42.29907817,94,115.6452041,30.92015417
# 73,44.65283424,89,111.1853528,29.36334142
# 92,39.3540941,50,117.5985128,15.75353468
#
# There is a file by this name
# This runs always in the Finllay

# %% [markdown]
# another example

# %%
try: 
    #run the code
    f = open("Cars1.csv", "r")
    print(f.read())

except:
    #executes the code when there is an exception
    print("There is not file by this name")
else: 
    #executes the code when thre is NO exception
    print("There is a file by this name")
finally: 
    f.close()
    #executes the code the code always
    print("This runs always in the Finllay")
# Out:
# There is not file by this name
# This runs always in the Finllay

# %%
a=100/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-135-cc2640765277> in <module>
# ----> 1 a=100/0
#
# ZeroDivisionError: division by zero

# %%
try: 
    #run the code
    #f = open("Cars1.csv", "r")
    #print(f.read())
    a=100/0
    #print(t)

except FileNotFoundError as e:
    #executes the code when there is an exception
       print(e)
    
except ZeroDivisionError:
    #executes the code when there is an exception
      print("ZeroDivisionError")

except SyntaxError:
    #executes the code when there is an exception
      print("This is a Syntax Error")



#else: 
    #executes the code when thre is NO exception
    #print("There is a file by this name")
#finally: 
#    f.close()
    #executes the code the code always
    #print("This runs always in the Finllay")
# Out:
# ZeroDivisionError

# %%
try: 
    #run the code
    f = open("Cars1.csv", "r")
    print(f.read())

except FileNotFoundError:
    #executes the code when there is an exception
       print(FileNotFoundError)



#else: 
    #executes the code when thre is NO exception
    #print("There is a file by this name")
#finally: 
#    f.close()
    #executes the code the code always
    #print("This runs always in the Finllay")
# Out:
# <class 'FileNotFoundError'>

# %% [markdown]
# # Generic Approach for errors

# %%
try: 
    #run the code
    #a=100/0
    f = open("Cars.csv", "r")
    print(f.read())
    
except FileNotFoundError as e:
    #executes the code when there is an exception
       print("Error occured:",e)
except ZeroDivisionError as e:
    #executes the code when there is an exception
       print("Error occured:",e)
        
except Exception as e:
    #executes the code when there is an exception
      print("Error occured:",e)
    
else: 
    #executes the code when thre is NO exception
    print("There is a file by this name-else")
finally: 
    f.close()
    #executes the code the code always
    print("This runs always in the Finllay")
# Out:
# HP,MPG,VOL,SP,WT
# 49,53.70068138,89,104.1853528,28.7620589
# 55,50.01340115,92,105.4612635,30.46683298
# 55,50.01340115,92,105.4612635,30.19359657
# 70,45.69632238,92,113.4612635,30.63211391
# 53,50.50423183,92,104.4612635,29.88914864
# 70,45.69632238,89,113.1853528,29.59176832
# 55,50.01340115,92,105.4612635,30.30847957
# 62,46.71655428,50,102.5985128,15.84775807
# 62,46.71655428,50,102.5985128,16.35948352
# 80,42.29907817,94,115.6452041,30.92015417
# 73,44.65283424,89,111.1853528,29.36334142
# 92,39.3540941,50,117.5985128,15.75353468
#
# There is a file by this name-else
# This runs always in the Finllay

# %% [markdown]
# # using the Key word Raise

# %%
try:
    even = int(input('Please enter an even number:'))
    if even % 2 != 0:
        print('a')
        raise ValueError("Error: You did not provide an even number")
except Exception as e:
    print(e)

except ValueError as e:
    print(e)
# Out:
# Please enter an even number:5
# a
# Error: You did not provide an even number

# %% [markdown]
# # End of Basics of Python and Python Constructs
