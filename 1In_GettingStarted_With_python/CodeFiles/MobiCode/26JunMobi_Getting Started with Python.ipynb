# %% [markdown]
# # Getting Started with Python

# %% [markdown]
# 26 June 2020

# %% [markdown]
# Assigning variables in Python

# %%
a=10
name="Victor"
#name=10
salary=2000.3

print(a)
print(name)
print(salary)
# Out:
# 10
# Victor
# 2000.3

# %% [markdown]
# See the datypes

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(salary))
# Out:
# <class 'float'>

# %% [markdown]
# Assigning multiple values to a variable

# %%
a=b=c=10
print(a)
print(c)
x,y,z=10,20,30
print(x)
print(z)
# Out:
# 10
# 10
# 10
# 30

# %%
x,y,z=10,20
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-62a22b664d46> in <module>
# ----> 1 x,y,z=10,20
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# # String Literals

# %%
name1="John"
name2="james"
print(name1)
print(name2)

#multiline using \
text1='hello\
world'
print(text1)
text2='hello \
world'

print(text2)

#multiline in the print ''' .....'''
multiline ='''st1
......String2
......String3
'''
print(multiline)
# Out:
# John
# james
# helloworld
# hello world
# st1
# ......String2
# ......String3

# %% [markdown]
# # Special Literals

# %%
val1=10
val2 =None
val4=''
val3='None'
print(val1)
print(val2)
print(val1,val2)
print(type(val2))
print(type(val3))
val2=200
print(val2)
# Out:
# 10
# None
# 10 None
# <class 'NoneType'>
# <class 'str'>
# 200

# %% [markdown]
# # Operators +,-*,/,%

# %%
1+2
# Out:
# 3

# %%
1-2
# Out:
# -1

# %%
3*6
# Out:
# 18

# %%
2%1
# Out:
# 0

# %% [markdown]
# # How to use the intellisense in jupyter

# %% [markdown]
# press a first or 2 alphabets and press the tab.

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bca0e2660b9f> in <module>
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Assignment operators, Assign values

# %%
a =10
print(a)
# Out:
# 10

# %%
b = 10*10
print(b)

c *=10
print(c)

#d *=15
#print(d)
# Out:
# 100
# 1000

# %% [markdown]
# # Comparision Operators: <,>,<=,>=, !=,==

# %%
a = 10
b= 20
a > b
# Out:
# False

# %%
a = 10
b= 20
a != b
# Out:
# True

# %%
a==b
# Out:
# False

# %% [markdown]
# # Numbers /Integers

# %%
a =10
print(a)
# Out:
# 10

# %% [markdown]
# # Strings

# %%
str1 = 'Hello-World!'
str2 = 'PythonTutorial1'
str.
print(str1[0])
print(str2[1:5])
#the 1 is inclusive, and 5 is exclusive
# Out:
# H
# ytho

# %% [markdown]
# # find()

# %%
str="Attachment"
str.find('me')
str.find('Me')
# Out:
# -1

# %%
str.replace('me','aa')
# Out:
# 'Attachaant'

# %%
strsplit1= 'word1,word2,word3'
strsplit1.split(',')
print(strsplit1)

str2=strsplit1.split(',')
print(str2[0])
# Out:
# word1,word2,word3
# word1

# %% [markdown]
# # Tuples

# %%
myGroup =('')
