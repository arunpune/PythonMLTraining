# %% [markdown]
# # Employee (Name, Salary, Employee Count)-Training

# %% [markdown]
# # Creating Classes

# %% [markdown]
# The class statement creates a new class definition. The name of the class immediately follows the keyword class followed by a colon as follows −

# %%
dir(Employee)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'displayCount',
#  'displayEmployee',
#  'empCount']

# %%
class Employee(object):
   'Common base class for all employees'
   empCount = 0

   def __init__(self, name, salary):
      self.name = name
      self.salary = salary
      Employee.empCount += 1
   
   def displayCount(self):
     print ("Total Employee %d" % Employee.empCount)

   def displayEmployee(self):
      print ("Name : ", self.name,  ", Salary: ", self.salary)

# %% [markdown]
# # Creating Instance Objects

# %% [markdown]
# To create instances of a class, you call the class using class name and pass in whatever arguments its __init__ method accepts.

# %%
emp1 = Employee("Zara",2000)
emp1.displayEmployee()

#"This would create first object of Employee class"

#emp1 = Employee("Zara", 2000)
#"This would create second object of Employee class"


emp2 = Employee("Allen", 5000)
emp3 = Employee("Anil",6000)
# Out:
# Name :  Zara , Salary:  2000

# %% [markdown]
# # Accessing Attributes

# %% [markdown]
# You access the object's attributes using the dot operator with object. Class variable would be accessed using class name as follows −

# %%
emp1.displayEmployee()
emp2.displayEmployee()
emp3.displayEmployee()
print ("Total Employee %d" % Employee.empCount)
# Out:
# Name :  Zara , Salary:  2000
# Name :  Allen , Salary:  5000
# Name :  Anil , Salary:  6000
# Total Employee 6

# %% [markdown]
# # Putting it all together to make a programs

# %%
class Employee:
   'Common base class for all employees'
   empCount = 0

   def __init__(self, name, salary):
      self.name = name
      self.salary = salary
      
      Employee.empCount += 1
   
   def displayCount(self):
     print ("Total Employee %d" % Employee.empCount)

   def displayEmployee(self):
      print ("Name : ", self.name,  ", Salary: ", self.salary)

# %% [markdown]
# create the objects of Employee Class

# %%
"This would create first object of Employee class"
emp1 = Employee("Zara", 2000)
"This would create second object of Employee class"
#emp2 = Employee("Manni", 5000)
emp1.displayEmployee()
#emp2.displayEmployee()
print ("Total Employee %d" % Employee.empCount)
# Out:
# Name :  Zara , Salary:  2000
# Total Employee 7

# %% [markdown]
# # Make changes to the Data in the Program

# %% [markdown]
# You can add, remove, or modify attributes of classes and objects at any time

# %%
emp1.age = 7  # Add an 'age' attribute.
print ("Employee Age %d" % emp1.age)
emp1.age = 8  # Modify 'age' attribute.
print ("Employee Age %d" % emp1.age)
#emp1.displayEmployee()
#The Following will give you an error because the age attribute is removed
del emp1.age  # Delete 'age' attribute.
print ("Employee Age %d" % emp1.age)
# Out:
# Employee Age 7
# Employee Age 8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cd13ff634236> in <module>
#       6 #The Following will give you an error because the age attribute is removed
#       7 del emp1.age  # Delete 'age' attribute.
# ----> 8 print ("Employee Age %d" % emp1.age)
#
# AttributeError: 'Employee' object has no attribute 'age'

# %% [markdown]
# # Different ways of Accessing the Data

# %% [markdown]
# Instead of using the normal statements to access attributes, you can use the following functions −
#
#
# The hasattr(obj,name) − to check if an attribute exists or not.
#
# The getattr(obj, name[, default]) − to access the attribute of object.
#
# The setattr(obj,name,value) − to set an attribute. If attribute does not exist, then it would be created.
#
# The delattr(obj, name) − to delete an attribute.

# %%
emp1.age = 7  # Add an 'age' attribute.


print(hasattr(emp1, 'age'))    # Returns true if 'age' attribute exists
print(getattr(emp1, 'age'))    # Returns value of 'age' attribute
print(setattr(emp1, 'age', 8)) # Set attribute 'age' at 8
print(getattr(emp1, 'age')) 
#print(delattr(empl, 'age'))    # Delete attribute 'age'- it will throw an error
# Out:
# True
# 7
# None
# 8
