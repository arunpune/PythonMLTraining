# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
'''
    1. Load cars data as dataframe using pandas and create a bar plot between number of cylinders and frequncy of cars with that 
       many number of cylinders.
       1. Set xlabel as Number of cylinders.
       2. Set ylabel as  Frequency of cars.
       3. Draw a bar plot.
'''
data = pd.read_csv('cars.csv')

# %%
plt.xlabel('Number of cylinders')
plt.ylabel('Frequency')
#plt.bar(list(count.index), list(count.get_values()))
#plt.bar(data., list(count.get_values()))
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#data['cyl'].value_counts()
#data['cyl'].unique
#data['cyl'].groupby
#plt.bar(data.['cyl'].unique,data['cyl'].value_counts() )

#data['cyl'].value_counts().plot(kind='bar')
data['cyl'].value_counts().plot.bar(x=frequency)

#data['cyl'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-4dccfd90fad4> in <module>
#       5
#       6 #data['cyl'].value_counts().plot(kind='bar')
# ----> 7 data['cyl'].value_counts().plot.bar(x=frequency)
#       8
#       9 #data['cyl'].plot.bar()
#
# NameError: name 'frequency' is not defined

# %%
data.head()

# %%
'''
    2. Write code to load data fromc cars and print a bar graph of count of columns with null values
'''
ans = data.isnull().sum()
plt.bar(ans.index, ans.get_values())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5da7c9e959d8> in <module>
#       3 '''
#       4 ans = data.isnull().sum()
# ----> 5 plt.bar(ans.index, ans.get_values())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'get_values'

# %%
'''
    3. Use the 'mpg' (Miles Per Gallon column) and draw a histogram
      i. Set xlabel: Miles per gallon
      ii. Set ylabel: Frequency
      iii. Set title as Miles Per Gallon Histogram
      iv. Use mpg column to generate a histogram
'''
plt.xlabel('Miles per gallon')
plt.ylabel('Frequency')
plt.title('Miles Per Gallon Histogram')
plt.hist(data.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <a list of 10 Patch objects>)

# %%
'''
    4. Draw a boxplot on the card dataframes hp column
      i. Set xlabel: Car Horsepower
      ii. Set title as Boxplot for car horsepower
      iii. Use hp column to generate a boxplot
'''
plt.title('Boxplot for car horsepower')
plt.xlabel('Car Horsepower')
plt.boxplot(data.hp, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2db25c9e2c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2db25cb0d08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2db25c77948>],
#  'medians': [<matplotlib.lines.Line2D at 0x2db25cb6cc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2db25cb6e08>],
#  'means': [<matplotlib.lines.Line2D at 0x2db25cb6d88>]}
